# %%
! pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\pbutler15\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\pbutler15\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)

# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from pprint import pprint


# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %%
#Generate Cities

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

response = requests.get(query_url + city)
weather_json = response.json()
pprint(weather_json)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -34.42, 'lon': 19.23},
#  'dt': 1603148163,
#  'id': 3366880,
#  'main': {'feels_like': 55.54,
#           'humidity': 85,
#           'pressure': 1017,
#           'temp': 57,
#           'temp_max': 57,
#           'temp_min': 57},
#  'name': 'Hermanus',
#  'rain': {'1h': 0.18},
#  'sys': {'country': 'ZA',
#          'id': 2006131,
#          'sunrise': 1603166064,
#          'sunset': 1603213255,
#          'type': 3},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 228, 'gust': 10, 'speed': 4}}

# %%
 #Perform API Calls

#Perform a weather check on each city using a series of successive API calls.
#Include a print log of each city as it's being processed (with the city number and city name)
# set up lists to hold reponse info
city_name=[]
lat = []
lng=[]
max_temp = []
humidity=[]
cloudiness=[]
wind_speed=[]
country=[]
date=[]
city_record =[]

# Print Starting Log Statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Processing Record start
processing_record = 1

# Loop through the list of cities and perform a request for data on each
for city in cities:

    #Excecption Handling
    try:
        response = requests.get(query_url + city).json()
        print(f"Processing Record {processing_record} | {city_record}")
        processing_record += 1
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city_record = response["name"]
    
    except:
        print(f"{city} not found. Skipping...") 
        time.sleep(10)

# Print Ending Log Statement
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | []
# Processing Record 2 | Philadelphia
# Processing Record 3 | Ushuaia
# Processing Record 4 | Ribeira Grande
# Processing Record 5 | Ørnes
# Processing Record 6 | Baruun-Urt
# Processing Record 7 | Saint-Philippe
# Processing Record 8 | Touros
# Processing Record 9 | Grand Gaube
# Processing Record 10 | Caravelas
# Processing Record 11 | Esim
# Processing Record 12 | Saint George
# Processing Record 13 | Punta Arenas
# Processing Record 14 | São Félix do Xingu
# Processing Record 15 | Daru
# Processing Record 16 | Upernavik
# Processing Record 17 | Kushima
# Processing Record 18 | Katangli
# Processing Record 19 | Jamestown
# Processing Record 20 | Hobart
# Processing Record 21 | Arrondissement de Muret
# Processing Record 22 | Albany
# Processing Record 23 | Ponta do Sol
# Processing Record 24 | Atuona
# Processing Record 25 | Butaritari
# Processing Record 26 | George Town
# Processing Record 27 | Rikitea
# Processing Record 28 | Arraial do Cabo
# Processing Record 29 | Mataura
# Processing Record 30 | Airai
# Processing Record 31 | Bento Gonçalves
# Processing Record 32 | Severo-Kuril'sk
# Processing Record 33 | Lhokseumawe
# Processing Record 34 | Ladozhskaya
# Processing Record 35 | Faanui
# Processing Record 36 | Souillac
# Processing Record 37 | Kruisfontein
# Processing Record 38 | Cockburn Town
# Processing Record 39 | Jalu
# Processing Record 40 | Tarnów
# Processing Record 41 | Muncar
# Processing Record 42 | Iguape
# Processing Record 43 | Taltal
# Processing Record 44 | Talnakh
# Processing Record 45 | Cayenne
# Processing Record 46 | Kasama
# taolanaro not found. Skipping...
# Processing Record 47 | Kasama
# Processing Record 48 | Lagoa
# Processing Record 49 | Novikovo
# Processing Record 50 | Constitución
# Processing Record 51 | Chokurdakh
# Processing Record 52 | Saiha
# Processing Record 53 | Port Keats
# Processing Record 54 | Omsukchan
# illoqqortoormiut not found. Skipping...
# Processing Record 55 | Omsukchan
# Processing Record 56 | Aljezur
# Processing Record 57 | Coruripe
# Processing Record 58 | Mahébourg
# Processing Record 59 | Campbell River
# Processing Record 60 | Saint Paul Harbor
# Processing Record 61 | Guerrero Negro
# Processing Record 62 | Geraldton
# samusu not found. Skipping...
# Processing Record 63 | Geraldton
# Processing Record 64 | Belaya Gora
# Processing Record 65 | Salalah
# Processing Record 66 | Egvekinot
# Processing Record 67 | Qaanaaq
# Processing Record 68 | Muisne
# Processing Record 69 | Kununurra
# Processing Record 70 | Yar-Sale
# Processing Record 71 | Coquimbo
# Processing Record 72 | Castro
# Processing Record 73 | Kahului
# Processing Record 74 | Kuching
# Processing Record 75 | Vaini
# Processing Record 76 | Lékoni
# Processing Record 77 | Kastornoye
# Processing Record 78 | Tromsø
# Processing Record 79 | Port Hardy
# Processing Record 80 | Cape Town
# belushya guba not found. Skipping...
# Processing Record 81 | Cape Town
# anar darreh not found. Skipping...
# Processing Record 82 | Cape Town
# Processing Record 83 | Korla
# Processing Record 84 | Uvalde
# Processing Record 85 | Busselton
# Processing Record 86 | Muravlenko
# Processing Record 87 | Bilibino
# Processing Record 88 | Chui
# Processing Record 89 | Mar del Plata
# Processing Record 90 | East London
# Processing Record 91 | Dikson
# Processing Record 92 | Sandpoint
# Processing Record 93 | Port Alfred
# Processing Record 94 | Utena
# Processing Record 95 | Khatanga
# Processing Record 96 | Kavieng
# Processing Record 97 | Dongsheng
# Processing Record 98 | Port Elizabeth
# Processing Record 99 | Hay River
# Processing Record 100 | Ilulissat
# Processing Record 101 | Zhigansk
# Processing Record 102 | Faranah
# Processing Record 103 | Bluff
# Processing Record 104 | Tuatapere
# Processing Record 105 | Saskylakh
# Processing Record 106 | Yellowknife
# Processing Record 107 | Fomento
# Processing Record 108 | Gumdag
# Processing Record 109 | Murgab
# el balyana not found. Skipping...
# Processing Record 110 | Murgab
# Processing Record 111 | Sabzawār
# Processing Record 112 | Carnarvon
# Processing Record 113 | Mbini
# Processing Record 114 | Narsaq
# Processing Record 115 | Hermanus
# Processing Record 116 | Karratha
# Processing Record 117 | Bonavista
# mocambique not found. Skipping...
# Processing Record 118 | Bonavista
# Processing Record 119 | Barrow
# Processing Record 120 | Cherskiy
# Processing Record 121 | Klaksvík
# grimari not found. Skipping...
# Processing Record 122 | Klaksvík
# Processing Record 123 | Tuktoyaktuk
# Processing Record 124 | Ugoofaaru
# Processing Record 125 | Dwārka
# Processing Record 126 | Mweka
# Processing Record 127 | Tazovsky
# Processing Record 128 | Glazov
# Processing Record 129 | Puerto Ayora
# Processing Record 130 | Alice Springs
# Processing Record 131 | Tual
# Processing Record 132 | Cidreira
# Processing Record 133 | Bang Saphan
# Processing Record 134 | Yangi Marg`ilon
# Processing Record 135 | Hithadhoo
# Processing Record 136 | Harindānga
# kamenskoye not found. Skipping...
# Processing Record 137 | Harindānga
# Processing Record 138 | Sangar
# Processing Record 139 | New Norfolk
# Processing Record 140 | Te Anau
# Processing Record 141 | Nanortalik
# Processing Record 142 | Rock Springs
# Processing Record 143 | Carnot
# Processing Record 144 | Kumluca
# Processing Record 145 | Husavik
# Processing Record 146 | Coyhaique
# Processing Record 147 | Canatlán
# Processing Record 148 | Bathsheba
# Processing Record 149 | Kandrian
# Processing Record 150 | Morón
# grand river south east not found. Skipping...
# Processing Record 151 | Morón
# Processing Record 152 | Coahuayana Viejo
# Processing Record 153 | Abonnema
# Processing Record 154 | Nikolskoye
# Processing Record 155 | Tolaga Bay
# Processing Record 156 | Kaitangata
# Processing Record 157 | Vao
# barentsburg not found. Skipping...
# Processing Record 158 | Vao
# Processing Record 159 | Dalbandin
# Processing Record 160 | Mitsamiouli
# Processing Record 161 | Bengkulu
# Processing Record 162 | Mazagão
# Processing Record 163 | Naze
# Processing Record 164 | San-Pédro
# Processing Record 165 | Narovchat
# Processing Record 166 | Thompson
# Processing Record 167 | Tasiilaq
# Processing Record 168 | Qui Nhon
# Processing Record 169 | North Bend
# Processing Record 170 | Zabid
# Processing Record 171 | Cam Ranh
# Processing Record 172 | Fortuna
# Processing Record 173 | Aksarka
# Processing Record 174 | San Patricio
# Processing Record 175 | Lata
# Processing Record 176 | Pahrump
# Processing Record 177 | Linguère
# Processing Record 178 | Lebu
# Processing Record 179 | Muhafazat Lahij
# Processing Record 180 | Bredasdorp
# Processing Record 181 | Grindavik
# Processing Record 182 | Tungor
# Processing Record 183 | Antofagasta
# Processing Record 184 | Morant Bay
# Processing Record 185 | Margate
# mys shmidta not found. Skipping...
# Processing Record 186 | Margate
# Processing Record 187 | Morondava
# saleaula not found. Skipping...
# Processing Record 188 | Morondava
# Processing Record 189 | Port Blair
# Processing Record 190 | Faya
# Processing Record 191 | Qaqortoq
# Processing Record 192 | Baykal'sk
# Processing Record 193 | Havøysund
# Processing Record 194 | Sørland
# Processing Record 195 | Hūn
# Processing Record 196 | Laguna
# Processing Record 197 | Taldan
# Processing Record 198 | Oussouye
# Processing Record 199 | Dunmore Town
# Processing Record 200 | Diamantino
# ouro preto do oeste not found. Skipping...
# Processing Record 201 | Stornoway
# Processing Record 202 | Mariehamn
# barbar not found. Skipping...
# Processing Record 203 | Mariehamn
# Processing Record 204 | São João da Barra
# Processing Record 205 | Saint-Pierre
# Processing Record 206 | Otavi
# dzhusaly not found. Skipping...
# Processing Record 207 | Otavi
# Processing Record 208 | Hamilton
# aflu not found. Skipping...
# Processing Record 209 | Ponta Delgada
# Processing Record 210 | Evanston
# Processing Record 211 | Druzhba
# Processing Record 212 | Zwedru
# Processing Record 213 | Tiksi
# basyanovskiy not found. Skipping...
# Processing Record 214 | Tiksi
# Processing Record 215 | Chu
# Processing Record 216 | Plettenberg Bay
# Processing Record 217 | Denpasar
# nguiu not found. Skipping...
# Processing Record 218 | Denpasar
# Processing Record 219 | Vardø
# Processing Record 220 | San Cristobal
# Processing Record 221 | Ushumun
# Processing Record 222 | Datong
# Processing Record 223 | Keti Bandar
# amderma not found. Skipping...
# Processing Record 224 | Keti Bandar
# Processing Record 225 | Kulunda
# Processing Record 226 | Dongying
# Processing Record 227 | Mangai
# karauzyak not found. Skipping...
# Processing Record 228 | Mangai
# Processing Record 229 | Lieto
# Processing Record 230 | Kysyl-Syr
# Processing Record 231 | Kapaa
# Processing Record 232 | Dingle
# Processing Record 233 | Port Augusta
# Processing Record 234 | Aklavik
# Processing Record 235 | Pevek
# el faiyum not found. Skipping...
# Processing Record 236 | Pevek
# Processing Record 237 | Vwawa
# Processing Record 238 | Tulun
# Processing Record 239 | Findlay
# Processing Record 240 | Mineiros
# Processing Record 241 | Asău
# Processing Record 242 | Sitka
# Processing Record 243 | Bethel
# Processing Record 244 | Ayr
# Processing Record 245 | Great Yarmouth
# Processing Record 246 | Ormož
# Processing Record 247 | Sinop Province
# Processing Record 248 | General Roca
# Processing Record 249 | Fes
# Processing Record 250 | Srednekolymsk
# Processing Record 251 | Esperance
# Processing Record 252 | Burē
# Processing Record 253 | Porto Belo
# Processing Record 254 | Takoradze
# Processing Record 255 | Yumen
# Processing Record 256 | Hilo
# Processing Record 257 | Ust'-Omchug
# Processing Record 258 | Chapais
# Processing Record 259 | Mayumba
# Processing Record 260 | Vila Velha
# Processing Record 261 | Leningradskiy
# Processing Record 262 | Novaya Igirma
# Processing Record 263 | Rakaia
# tarudant not found. Skipping...
# Processing Record 264 | Rakaia
# Processing Record 265 | Doha
# Processing Record 266 | Contamana
# Processing Record 267 | Port Hedland
# Processing Record 268 | Iqaluit
# Processing Record 269 | Provideniya
# tidore not found. Skipping...
# Processing Record 270 | Provideniya
# tsihombe not found. Skipping...
# Processing Record 271 | Provideniya
# Processing Record 272 | Mastic Beach
# sentyabrskiy not found. Skipping...
# Processing Record 273 | Mastic Beach
# Processing Record 274 | Hasaki
# Processing Record 275 | Anadyr
# nizhneyansk not found. Skipping...
# Processing Record 276 | Anadyr
# Processing Record 277 | Samarai
# Processing Record 278 | Hilton Head
# Processing Record 279 | Padang
# Processing Record 280 | Saquena
# Processing Record 281 | Hong Kong
# Processing Record 282 | Dapdap
# Processing Record 283 | Mahon
# Processing Record 284 | Japura
# Processing Record 285 | Lębork
# Processing Record 286 | Belyy Yar
# Processing Record 287 | Kabalo
# Processing Record 288 | Lüshunkou
# Processing Record 289 | Beckley
# Processing Record 290 | Voyvozh
# Processing Record 291 | Rome
# Processing Record 292 | Māngrol
# Processing Record 293 | Jacareacanga
# Processing Record 294 | Carberry
# Processing Record 295 | Avarua
# Processing Record 296 | Cabo San Lucas
# Processing Record 297 | Abu Dhabi
# Processing Record 298 | Guánica
# Processing Record 299 | Hengshui
# Processing Record 300 | Kiryat Gat
# Processing Record 301 | Chisec
# Processing Record 302 | Alyangula
# Processing Record 303 | Lakatoro
# Processing Record 304 | Rocha
# Processing Record 305 | Padong
# Processing Record 306 | Portsmouth
# Processing Record 307 | Atherton
# Processing Record 308 | Baguanos
# Processing Record 309 | Nicoya
# Processing Record 310 | Katsuura
# Processing Record 311 | Tadpatri
# valjala not found. Skipping...
# Processing Record 312 | Tadpatri
# Processing Record 313 | Poum
# Processing Record 314 | Florenville
# Processing Record 315 | Trincomalee
# Processing Record 316 | Evensk
# Processing Record 317 | Muros
# Processing Record 318 | Hidalgo
# Processing Record 319 | Najrān
# Processing Record 320 | Tilichiki
# Processing Record 321 | Ancud
# Processing Record 322 | Road Town
# Processing Record 323 | Nelson Bay
# Processing Record 324 | Paamiut
# Processing Record 325 | Ziro
# Processing Record 326 | Igualada
# Processing Record 327 | Segamat
# Processing Record 328 | Øksfjord
# Processing Record 329 | Bassar
# Processing Record 330 | Soledad
# Processing Record 331 | Griffith
# Processing Record 332 | Bria
# Processing Record 333 | Molokovo
# Processing Record 334 | Champerico
# Processing Record 335 | Vestmanna
# Processing Record 336 | Corpus Christi
# Processing Record 337 | Barra de Tecoanapa
# Processing Record 338 | Huilong
# jabiru not found. Skipping...
# Processing Record 339 | Huilong
# Processing Record 340 | Lilongwe
# Processing Record 341 | Ambon City
# Processing Record 342 | Praia da Vitória
# Processing Record 343 | Nome
# Processing Record 344 | Mabaruma
# Processing Record 345 | Yetkul'
# Processing Record 346 | Bolshoy Lug
# Processing Record 347 | Colinas
# Processing Record 348 | Paraná
# Processing Record 349 | Victor Harbor
# Processing Record 350 | Broken Hill
# Processing Record 351 | Sola
# Processing Record 352 | Dŭstí
# Processing Record 353 | Toamasina
# Processing Record 354 | Springdale
# Processing Record 355 | Flinders
# Processing Record 356 | Kemijärvi
# inderborskiy not found. Skipping...
# Processing Record 357 | Kemijärvi
# Processing Record 358 | Lorengau
# vaitupu not found. Skipping...
# Processing Record 359 | Lorengau
# Processing Record 360 | Halmstad
# Processing Record 361 | Norman Wells
# mizpe ramon not found. Skipping...
# Processing Record 362 | Norman Wells
# Processing Record 363 | Krasnosel'kup
# beruni not found. Skipping...
# Processing Record 364 | Krasnosel'kup
# Processing Record 365 | Bhongīr
# Processing Record 366 | Saint-Joseph
# Processing Record 367 | Lendava
# Processing Record 368 | Dinard
# Processing Record 369 | Pilar
# Processing Record 370 | Flin Flon
# Processing Record 371 | Goedereede
# Processing Record 372 | Carutapera
# Processing Record 373 | İzmir
# Processing Record 374 | Makakilo City
# Processing Record 375 | Olinda
# Processing Record 376 | Yatou
# Processing Record 377 | Mount Gambier
# Processing Record 378 | Codrington
# Processing Record 379 | Deniliquin
# Processing Record 380 | Waddān
# Processing Record 381 | Hofn
# Processing Record 382 | Dunedin
# Processing Record 383 | Mananjary
# Processing Record 384 | Pamekasan
# Processing Record 385 | Yabrūd
# Processing Record 386 | Saint-Augustin
# Processing Record 387 | Kaitong
# Processing Record 388 | Comodoro Rivadavia
# Processing Record 389 | Bud
# Processing Record 390 | Tabou
# Processing Record 391 | Kapoeta
# Processing Record 392 | Agadez
# Processing Record 393 | Kirensk
# malwan not found. Skipping...
# Processing Record 394 | Kirensk
# Processing Record 395 | Oranjemund
# Processing Record 396 | Beira
# Processing Record 397 | Manta
# Processing Record 398 | Houma
# Processing Record 399 | Haizhou
# Processing Record 400 | Basco
# Processing Record 401 | Danjiangkou
# Processing Record 402 | Ostrovnoy
# Processing Record 403 | Benicarló
# Processing Record 404 | Loknya
# Processing Record 405 | Inhambane
# Processing Record 406 | Tongchuanshi
# Processing Record 407 | Labuhan
# Processing Record 408 | Shahr-e Kord
# tabialan not found. Skipping...
# Processing Record 409 | Shahr-e Kord
# Processing Record 410 | Ekhabi
# Processing Record 411 | Moree
# Processing Record 412 | Oktyabr'skiy
# Processing Record 413 | Manitouwadge
# Processing Record 414 | Mossamedes
# Processing Record 415 | Ust'-Barguzin
# Processing Record 416 | Riyadh
# Processing Record 417 | Isangel
# Processing Record 418 | Marabá
# Processing Record 419 | Bambous Virieux
# Processing Record 420 | Half Moon Bay
# Processing Record 421 | Balsas
# Processing Record 422 | San Andrés
# Processing Record 423 | Ruangwa
# Processing Record 424 | Fairbanks
# Processing Record 425 | Great Bend
# Processing Record 426 | Jinhua
# Processing Record 427 | Bereda
# Processing Record 428 | Poltavka
# kuche not found. Skipping...
# Processing Record 429 | Poltavka
# Processing Record 430 | Baturaja
# Processing Record 431 | Kokopo
# Processing Record 432 | Mahenge
# Processing Record 433 | Rafrāf
# Processing Record 434 | Storsteinnes
# Processing Record 435 | Sawākin
# Processing Record 436 | Zigong
# Processing Record 437 | Lima
# attawapiskat not found. Skipping...
# Processing Record 438 | Lima
# Processing Record 439 | Soe
# Processing Record 440 | Magadan
# Processing Record 441 | The Valley
# satitoa not found. Skipping...
# Processing Record 442 | The Valley
# Processing Record 443 | Am Timan
# addi ugri not found. Skipping...
# Processing Record 444 | Am Timan
# Processing Record 445 | Dakar
# Processing Record 446 | Mahon
# Processing Record 447 | Madera
# Processing Record 448 | Lesnoye
# Processing Record 449 | Lugovoy
# Processing Record 450 | Huarmey
# Processing Record 451 | Loa Janan
# Processing Record 452 | Toora-Khem
# Processing Record 453 | Kālīganj
# Processing Record 454 | Phang Nga
# Processing Record 455 | Cap Malheureux
# Processing Record 456 | Quepos
# dolbeau not found. Skipping...
# Processing Record 457 | Quepos
# Processing Record 458 | Ilo
# Processing Record 459 | Dolna Banjica
# Processing Record 460 | Arman'
# Processing Record 461 | Lithgow
# Processing Record 462 | Yuci
# Processing Record 463 | Solnechnyy
# Processing Record 464 | Coffs Harbour
# Processing Record 465 | Moerai
# Processing Record 466 | Longyearbyen
# Processing Record 467 | Saldanha
# Processing Record 468 | Parfen'yevo
# Processing Record 469 | Marathon
# Processing Record 470 | Xuanzhou
# Processing Record 471 | Deputatsky
# Processing Record 472 | Vostok
# Processing Record 473 | Lázaro Cárdenas
# Processing Record 474 | Tomatlán
# Processing Record 475 | Clyde River
# Processing Record 476 | Saryozek
# Processing Record 477 | Richards Bay
# marcona not found. Skipping...
# Processing Record 478 | Richards Bay
# Processing Record 479 | Rawson
# Processing Record 480 | Storforshei
# Processing Record 481 | Ol'ga
# Processing Record 482 | Kabanjahe
# Processing Record 483 | Wellington
# Processing Record 484 | Maniitsoq
# Processing Record 485 | Canals
# Processing Record 486 | Prestonpans
# Processing Record 487 | Swan Hill
# Processing Record 488 | Baykit
# Processing Record 489 | Güicán
# Processing Record 490 | Usinsk
# Processing Record 491 | Puertollano
# Processing Record 492 | Kūhdasht
# Processing Record 493 | Mattru
# Processing Record 494 | Villarrica
# Processing Record 495 | Djibo
# Processing Record 496 | Henties Bay
# bur gabo not found. Skipping...
# Processing Record 497 | Henties Bay
# Processing Record 498 | Lüderitz
# we not found. Skipping...
# Processing Record 499 | Lüderitz
# Processing Record 500 | Kurchum
# Processing Record 501 | Azanka
# bokspits not found. Skipping...
# Processing Record 502 | Azanka
# Processing Record 503 | Marquette
# Processing Record 504 | Nishihara
# Processing Record 505 | Kumul
# Processing Record 506 | Río Gallegos
# Processing Record 507 | Leh
# Processing Record 508 | Kralendijk
# Processing Record 509 | Xining
# Processing Record 510 | Long Eaton
# Processing Record 511 | Coulommiers
# Processing Record 512 | Harrisburg
# Processing Record 513 | Ciudad Real
# Processing Record 514 | Maningrida
# Processing Record 515 | Banda Aceh
# Processing Record 516 | Ahipara
# Processing Record 517 | Tommot
# Processing Record 518 | Talara
# Processing Record 519 | Ketchikan
# Processing Record 520 | Dabakala
# Processing Record 521 | Kirkwood
# Processing Record 522 | Ţahţā
# Processing Record 523 | Paranaíba
# Processing Record 524 | San Ignacio
# Processing Record 525 | Trat
# Processing Record 526 | Clifton
# Processing Record 527 | Port Moresby
# Processing Record 528 | Maryborough
# Processing Record 529 | Monrovia
# Processing Record 530 | Gafanha da Encarnação
# Processing Record 531 | Luba
# Processing Record 532 | Malanje
# Processing Record 533 | Khovd
# port-de-paix not found. Skipping...
# Processing Record 534 | Khovd
# Processing Record 535 | Saint-Paul
# umzimvubu not found. Skipping...
# Processing Record 536 | Saint-Paul
# Processing Record 537 | Nyurba
# Processing Record 538 | Bozeman
# Processing Record 539 | Bairiki Village
# Processing Record 540 | Xichang
# grande-riviere not found. Skipping...
# Processing Record 541 | Xichang
# Processing Record 542 | Ostrołęka
# Processing Record 543 | George
# cheuskiny not found. Skipping...
# Processing Record 544 | George
# Processing Record 545 | Olafsvik
# Processing Record 546 | Bol
# kusk not found. Skipping...
# Processing Record 547 | Bol
# Processing Record 548 | Seoul
# Processing Record 549 | Tura
# Processing Record 550 | Basirpur
# andevoranto not found. Skipping...
# Processing Record 551 | Basirpur
# Processing Record 552 | Lancaster
# Processing Record 553 | Mgandu
# Processing Record 554 | Igurusi
# Processing Record 555 | Baker City
# Processing Record 556 | Fort Nelson
# Processing Record 557 | Farmington
# Processing Record 558 | Ca Mau
# Processing Record 559 | Parintins
# Processing Record 560 | Sorong
# Processing Record 561 | Harper
# Processing Record 562 | Kautokeino
# Processing Record 563 | Lavrentiya
# Processing Record 564 | Sri Aman
# Processing Record 565 | Boz
# Processing Record 566 | Igarka
# Processing Record 567 | Tonj
# Processing Record 568 | Matara
# Processing Record 569 | Santa Engracia
# lolua not found. Skipping...
# Processing Record 570 | Santa Engracia
# Processing Record 571 | Giza
# Processing Record 572 | Amahai
# Processing Record 573 | Hambantota
# Processing Record 574 | Portland
# Processing Record 575 | Gamba
# Processing Record 576 | Shingū
# Processing Record 577 | Boden
# Processing Record 578 | Bay Roberts
# Processing Record 579 | Kisanga
# Processing Record 580 | Soyo
# Processing Record 581 | Chapleau
# Processing Record 582 | Solhan
# Processing Record 583 | Oshnavīyeh
# Processing Record 584 | Okhotsk
# Processing Record 585 | Avera
# Processing Record 586 | Kudahuvadhoo
# Processing Record 587 | Kommunisticheskiy
# armacao dos buzios not found. Skipping...
# Processing Record 588 | Kommunisticheskiy
# Processing Record 589 | Sikasso
# Processing Record 590 | Tiznit Province
# Processing Record 591 | Eurajoki
# Processing Record 592 | Nemuro
# Processing Record 593 | Severoural'sk
# Processing Record 594 | Astoria
# Processing Record 595 | Kiunga
# Processing Record 596 | Oktyabr'skoye
# Processing Record 597 | Nuuk
# igarape-acu not found. Skipping...
# Processing Record 598 | Nuuk
# Processing Record 599 | Ocampo
# Processing Record 600 | Emba
# Processing Record 601 | Phan Thiet
# Processing Record 602 | Boa Vista
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
#Convert Raw Data to DataFrame
#Export the city data into a .csv.
#Display the DataFrame

city_data = pd.DataFrame({
    'City': city_record ,
    'Latitude': lat,
    'Longititude': lng,
    'Max Temp':max_temp,
    'Humidity':humidity,
    'Cloudiness':cloudiness,
    'Wind Speed':wind_speed,
    'Country':country,
    'Date':date})
city_data
# Out:
#       City  Latitude  Longititude  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Pisco     39.95       -75.16     64.99        68          75        4.70
# 1    Pisco    -54.80       -68.30     41.00        80          75       34.45
# 2    Pisco     38.52       -28.70     64.17        68          46       27.69
# 3    Pisco     66.87        13.71     33.01        76          98        5.82
# 4    Pisco     46.68       113.28     44.06        51         100       16.13
# ..     ...       ...          ...       ...       ...         ...         ...
# 546  Pisco     21.65      -101.50     65.68        40           4       12.10
# 547  Pisco     48.83        58.14     49.41        46           0        9.31
# 548  Pisco     10.93       108.10     77.31        86         100        3.83
# 549  Pisco      2.82       -60.67     89.60        52          94        4.70
# 550  Pisco    -13.70       -76.22     66.20        72           0       17.22
#
#     Country        Date
# 0        US  1603150247
# 1        AR  1603150249
# 2        PT  1603150473
# 3        NO  1603150523
# 4        MN  1603150523
# ..      ...         ...
# 546      MX  1603151306
# 547      KZ  1603151307
# 548      VN  1603151307
# 549      BR  1603151307
# 550      PE  1603151058
#
# [551 rows x 9 columns]

# %%
#Export city data into .csv file

city_data.to_csv("../WeatherPy/city_data.csv")

# %%
#Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#Save the plotted figures as .pngs.

plt.scatter(city_data["Latitude"], city_data["Max Temp"], facecolors="blue", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
plt.title("City Latitude vs. Max Temp")
plt.ylabel("Max Temp (°F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../WeatherPy/City_Latitude_vs_Max_Temperature.png")

# Show Plot
plt.show()

# %%
plt.scatter(city_data["Latitude"], city_data["Humidity"], facecolors="blue", marker="o", edgecolor="black")
# Incorporate Other Graph Properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../WeatherPy/City_Latitude_vs_Humidity.png")

# Show Plot
plt.show()

# %%
plt.scatter(city_data["Latitude"], city_data["Cloudiness"], facecolors="blue", marker="o", edgecolor="black")
# Incorporate Other Graph Properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../WeatherPy/City_Latitude_vs_Humidity.png")

# Show Plot
plt.show()

# %%
plt.scatter(city_data["Latitude"], city_data["Wind Speed"], facecolors="blue", marker="o", edgecolor="black")
# Incorporate Other Graph Properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../WeatherPy/City_Latitude_vs_Humidity.png")

# Show Plot
plt.show()

# %%
#run linear regression on each relationship, only this time separating them into Northern Hemisphere 
#(greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude)
northern = city_data.loc[city_data["Latitude"] >= 0.0]
southern = city_data.loc[city_data["Latitude"] < 0.0]

# %%
#Define plotting function
def plotLinearRegression(xdata,ydata,xlbl,ylbl,lblpos,ifig):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xdata, ydata)
    print(f"The r-squared is: {rvalue}")
    regress_values = xdata * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(xdata,ydata)
    plt.plot(xdata,regress_values,"r-")
    plt.annotate(line_eq,lblpos,fontsize=15,color="red")
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)
    plt.show()

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression

xlbl = "Latitude"
ylbl = "Max Temp"
lblpos = (0,25)
plotLinearRegression(northern[xlbl],northern[ylbl],xlbl,ylbl,lblpos,5)

# Save the figure
plt.savefig("../WeatherPy/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is: -0.874217794469143

# %%
#Southern Hemisphere - Max Temp vs. Latitude Linear Regression

xlbl = "Latitude"
ylbl = "Max Temp"
lblpos = (0,25)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.7914557419069637

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
xlbl = "Latitude"
ylbl = "Humidity"
lblpos = (45,10)
plotLinearRegression(northern[xlbl],northern[ylbl],xlbl,ylbl,lblpos,7)
# Out:
# The r-squared is: 0.1793151461098597

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
xlbl = "Latitude"
ylbl = "Humidity"
lblpos = (-55,15)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,8)
# Out:
# The r-squared is: 0.13407679504262093

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
xlbl = "Latitude"
ylbl = "Cloudiness"
lblpos = (20,40)
plotLinearRegression(northern[xlbl],northern[ylbl],xlbl,ylbl,lblpos,9)
# Out:
# The r-squared is: 0.2151600104614359

# %%
# Sourhern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
xlbl = "Latitude"
ylbl = "Cloudiness"
lblpos = (-55,50)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,10)
# Out:
# The r-squared is: 0.1194702142173205

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

xlbl = "Latitude"
ylbl = "Wind Speed"
lblpos = (0,30)
plotLinearRegression(northern[xlbl],northern[ylbl],xlbl,ylbl,lblpos,11)
# Out:
# The r-squared is: 0.10914643984730718

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
xlbl = "Latitude"
ylbl = "Wind Speed"
lblpos = (-25,33)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,12)
# Out:
# The r-squared is: -0.4195706648370837
